# %% [markdown]
# ## Open data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
unzip yolov5.zip
# Out:
# /content/gdrive/MyDrive

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !pip install -r requirements.txt

# %% [markdown]
# ## Train model

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 640 --batch 8 --epochs 10 --data models/data.yaml --weights yolov5x.pt
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=yolov5x.pt, cfg=, data=models/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 640 --batch 8 --epochs 10 --data models/data.yaml --weights runs/train/exp7/weights/best.pt
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=runs/train/exp7/weights/best.pt, cfg=, data=models/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# ## Test model

# %%
# %cd /content/gdrive/MyDrive/yolov5
from IPython.display import Image, clear_output
# !python detect.py --weights runs/train/exp7/weights/best.pt --img 640 --conf 0.3 --source data/images/train/f9192d70b8ae33af5fa02c6764e7457c.jpg
# Out:
# /content/gdrive/MyDrive/yolov5
# detect: weights=['runs/train/exp7/weights/best.pt'], source=data/images/train/f9192d70b8ae33af5fa02c6764e7457c.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 444 layers, 86260891 parameters, 0 gradients
# image 1/1 /content/gdrive/MyDrive/yolov5/data/images/train/f9192d70b8ae33af5fa02c6764e7457c.jpg: 640x576 1 Aortic enlargement, Done. (3.675s)
# Speed: 3.3ms pre-process, 3674.9ms inference, 12.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
Image(filename='runs/detect/exp3/f9192d70b8ae33af5fa02c6764e7457c.jpg', width=600)
